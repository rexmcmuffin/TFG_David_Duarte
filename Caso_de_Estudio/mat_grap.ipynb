# %% [markdown]
# Librerias requeridas

# %%
import h5py
import scipy.io
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Casos de estudio

# %% [markdown]
# Caso de estudio 1 - Filtro paso bajos

# %%
#with h5py.File(r"datos_filtro\simulados\Filtered_signal.mat", 'r') as archivo:
#    datos_simulados = archivo[list(archivo.keys())[0]][:]
datos_experimentales_raw = scipy.io.loadmat(r"datos_filtro\experimentales\Raw_signal.mat")
datos_experimentales_raw = datos_experimentales_raw[list(datos_experimentales_raw.keys())[0]]

datos_experimentales_filtered = scipy.io.loadmat(r"datos_filtro\experimentales\Filtered_signal.mat")
datos_experimentales_filtered = datos_experimentales_filtered[list(datos_experimentales_filtered.keys())[0]]


datos_simulados_raw = scipy.io.loadmat(r"datos_filtro\simulados\Raw_signal.mat")
datos_simulados_raw = datos_simulados_raw[list(datos_simulados_raw.keys())[0]]

datos_simulados_filtered = scipy.io.loadmat(r"datos_filtro\simulados\Filtered_signal.mat")
datos_simulados_filtered = datos_simulados_filtered[list(datos_simulados_filtered.keys())[0]]

# %%
tiempo_datos_experimentales_raw=datos_experimentales_raw[0]
valor_datos_experimentales_raw=datos_experimentales_raw[1]

tiempo_datos_experimentales_filtered =datos_experimentales_filtered[0]
valor_datos_experimentales_filtered =datos_experimentales_filtered[1]


tiempo_datos_simulados_raw=datos_simulados_raw[0]
valor_datos_simulados_raw=datos_simulados_raw[1]

tiempo_datos_simulados_filtered =datos_simulados_filtered[0]
valor_datos_simulados_filtered =datos_simulados_filtered[1]

# %% [markdown]
# Señal de salida simulada

# %%
plt.figure(figsize=(10, 5))
plt.plot(tiempo_datos_experimentales_raw, valor_datos_experimentales_raw, label='Señal de entrada')
plt.title('Señal de entrada experimental')
plt.xlabel('Tiempo [ms]')
plt.ylabel('Amplitud [V]')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Señal de salida experimental

# %%
plt.figure(figsize=(10, 5))
plt.plot(tiempo_datos_experimentales_filtered, valor_datos_experimentales_filtered, label='Señal filtrada')
plt.title('Señal filtrada experimental')
plt.xlabel('Tiempo [ms]')
plt.ylabel('Amplitud [V]')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Senal de entrada simulada

# %%
plt.figure(figsize=(10, 5))
plt.plot(tiempo_datos_simulados_raw, valor_datos_simulados_raw, label='Señal de entrada')
plt.title('Señal de entrada simulada')
plt.xlabel('Tiempo [ms]')
plt.ylabel('Amplitud [V]')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Senal de salida simulada

# %%
plt.figure(figsize=(10, 5))
plt.plot(tiempo_datos_simulados_filtered, valor_datos_simulados_filtered, label='Señal filtrada')
plt.title('Señal filtrada simulada')
plt.xlabel('Tiempo [ms]')
plt.ylabel('Amplitud [V]')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Métricas para la comparación de las señales del caso de estudio 1

# %%
# Supongamos que tienes dos vectores de datos ya cargados
vector1 = np.array(valor_datos_simulados)  # Datos del primer vector
vector2 = np.array(valor_datos_experimentales)  # Datos del segundo vector

# Calcular el error promedio absoluto (MAE)
mae = np.mean(np.abs(vector1 - vector2))
print(f"Error Promedio Absoluto (MAE): {mae}")

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = np.sqrt(np.mean((vector1 - vector2) ** 2))
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse}")

mse = np.mean((vector1 - vector2) ** 2)
print("Error Cuadrático Medio (MSE):", mse)

# %% [markdown]
# Caso de estudio 2 - IMU

# %%
with h5py.File(r"datos_imu\simulados\Gyroscope_Bias_sim.mat", 'r') as archivo:
    sesgo_simulado_del_giroscopio = archivo[list(archivo.keys())[0]][:]

with h5py.File(r"datos_imu\simulados\Orientation_Error_sim.mat", 'r') as archivo:
    error_de_orientacion_simulado = archivo[list(archivo.keys())[0]][:]

sesgo_del_giroscopio_experimental = scipy.io.loadmat(r'datos_imu\experimentales\Gyroscope_Bias.mat')
sesgo_del_giroscopio_experimental = sesgo_del_giroscopio_experimental[list(sesgo_del_giroscopio_experimental.keys())[0]]
error_de_orientacion_experimental = scipy.io.loadmat(r'datos_imu\experimentales\Orientation_Error.mat')
error_de_orientacion_experimental = error_de_orientacion_experimental[list(error_de_orientacion_experimental.keys())[0]]

# %%
tiempo_sesgo=sesgo_simulado_del_giroscopio[:,0]
sesgo_en_eje_x=sesgo_simulado_del_giroscopio[:,1]
sesgo_en_eje_y=sesgo_simulado_del_giroscopio[:,2]
sesgo_en_eje_z=sesgo_simulado_del_giroscopio[:,3]

tiempo_error_de_orientacion=error_de_orientacion_simulado[:,0]
error_de_orientacion=error_de_orientacion_simulado[:,1]

# %% [markdown]
# Sesgo simulado del giroscopio

# %%
plt.figure(figsize=(10, 5))
plt.plot(tiempo_sesgo, sesgo_en_eje_x, label='Eje x')
plt.plot(tiempo_sesgo, sesgo_en_eje_y, label='Eje Y')
plt.plot(tiempo_sesgo, sesgo_en_eje_z, label='Eje Z')
plt.title('Sesgo del Giroscopio simulado')
plt.xlabel('Tiempo [ms]')
plt.ylabel('Sesgo [°/ms]')
plt.legend()
plt.grid()
#plt.savefig('Filtered.pdf', format='pdf', dpi=600)  # Save as PDF with 300 DPI
plt.show()

# %% [markdown]
# Error de orientación simulado

# %%
plt.figure(figsize=(10, 5))
plt.plot(tiempo_error_de_orientacion, error_de_orientacion, label='Error de orientación')  # Add labels and title as necessary
plt.title('Error de orientación simulado')
plt.xlabel('Tiempo [ms]')
plt.ylabel('Error [%]')
plt.legend()
plt.grid()
#plt.savefig('Filtered.pdf', format='pdf', dpi=600)  # Save as PDF with 300 DPI
plt.show()

# %%
tiempo_sesgo_experimental=sesgo_del_giroscopio_experimental[0]
sesgo_en_eje_x_experimental=sesgo_del_giroscopio_experimental[1]
sesgo_en_eje_y_experimental=sesgo_del_giroscopio_experimental[2]
sesgo_en_eje_z_experimental=sesgo_del_giroscopio_experimental[3]

tiempo_error_de_orientacion_experimental=error_de_orientacion_experimental[0]
valor_error_de_orientacion_experimental=error_de_orientacion_experimental[1]

# %% [markdown]
# Sesgo del giroscopio experimental

# %%
plt.figure(figsize=(10, 5))
plt.plot(tiempo_sesgo_experimental, sesgo_en_eje_x_experimental, label='Eje x')
plt.plot(tiempo_sesgo_experimental, sesgo_en_eje_y_experimental, label='Eje Y')
plt.plot(tiempo_sesgo_experimental, sesgo_en_eje_z_experimental, label='Eje Z')
plt.title('Sesgo del Giroscopio experimental')
plt.xlabel('Tiempo [ms]')
plt.ylabel('Sesgo [°/ms]')
plt.legend()
plt.grid()
#plt.savefig('Filtered.pdf', format='pdf', dpi=600)  # Save as PDF with 300 DPI
plt.show()

# %% [markdown]
# Error de orientación experimental

# %%
plt.figure(figsize=(10, 5))
plt.plot(tiempo_error_de_orientacion_experimental, valor_error_de_orientacion_experimental, label='Error de orientación')  # Add labels and title as necessary
plt.title('Error de orientación experimental')
plt.xlabel('Tiempo [ms]')
plt.ylabel('Error [%]')
plt.legend()
plt.grid()
#plt.savefig('Filtered.pdf', format='pdf', dpi=600)  # Save as PDF with 300 DPI
plt.show()

# %% [markdown]
# Metricas del comparacion de las senales del caso de estudio 2

# %% [markdown]
# Sesgo eje x

# %%
import numpy as np

# Supongamos que tienes dos vectores de datos ya cargados
vector1 = np.array(sesgo_en_eje_x)  # Datos del primer vector
vector2 = np.array(sesgo_en_eje_x_experimental)  # Datos del segundo vector

# Calcular el error promedio absoluto (MAE)
mae = np.mean(np.abs(vector1 - vector2))
print(f"Error Promedio Absoluto (MAE): {mae}")

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = np.sqrt(np.mean((vector1 - vector2) ** 2))
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse}")

mse = np.mean((vector1 - vector2) ** 2)
print("Error Cuadrático Medio (MSE):", mse)
# Out:
# Error Promedio Absoluto (MAE): 2.312806764813304e-15
# Raíz del Error Cuadrático Medio (RMSE): 3.091235610298828e-15
# Error Cuadrático Medio (MSE): 9.555737598379567e-30

# %% [markdown]
# Sesgo eje y

# %%
# Supongamos que tienes dos vectores de datos ya cargados
vector1 = np.array(sesgo_en_eje_y)  # Datos del primer vector
vector2 = np.array(sesgo_en_eje_y_experimental)  # Datos del segundo vector

# Calcular el error promedio absoluto (MAE)
mae = np.mean(np.abs(vector1 - vector2))
print(f"Error Promedio Absoluto (MAE): {mae}")

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = np.sqrt(np.mean((vector1 - vector2) ** 2))
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse}")

mse = np.mean((vector1 - vector2) ** 2)
print("Error Cuadrático Medio (MSE):", mse)
# Out:
# Error Promedio Absoluto (MAE): 2.360130692916164e-15
# Raíz del Error Cuadrático Medio (RMSE): 3.2924481063003343e-15
# Error Cuadrático Medio (MSE): 1.0840214532680658e-29

# %% [markdown]
# Sesgo eje z

# %%
# Supongamos que tienes dos vectores de datos ya cargados
vector1 = np.array(sesgo_en_eje_z)  # Datos del primer vector
vector2 = np.array(sesgo_en_eje_z_experimental)  # Datos del segundo vector

# Calcular el error promedio absoluto (MAE)
mae = np.mean(np.abs(vector1 - vector2))
print(f"Error Promedio Absoluto (MAE): {mae}")

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = np.sqrt(np.mean((vector1 - vector2) ** 2))
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse}")

mse = np.mean((vector1 - vector2) ** 2)
print("Error Cuadrático Medio (MSE):", mse)
# Out:
# Error Promedio Absoluto (MAE): 3.1894094558210535e-15
# Raíz del Error Cuadrático Medio (RMSE): 4.580820759466871e-15
# Error Cuadrático Medio (MSE): 2.0983918830362644e-29

# %% [markdown]
# Error

# %%
# Supongamos que tienes dos vectores de datos ya cargados
vector1 = np.array(error_de_orientacion)  # Datos del primer vector
vector2 = np.array(valor_error_de_orientacion_experimental)  # Datos del segundo vector

# Calcular el error promedio absoluto (MAE)
mae = np.mean(np.abs(vector1 - vector2))
print(f"Error Promedio Absoluto (MAE): {mae}")

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = np.sqrt(np.mean((vector1 - vector2) ** 2))
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse}")

mse = np.mean((vector1 - vector2) ** 2)
print("Error Cuadrático Medio (MSE):", mse)
# Out:
# Error Promedio Absoluto (MAE): 1.2788931255722695e-13
# Raíz del Error Cuadrático Medio (RMSE): 2.124610139479325e-13
# Error Cuadrático Medio (MSE): 4.513968244778357e-26

# %% [markdown]
# Caso de estudio 3 - Controlador PID

# %%
with h5py.File(r"datos_pid\simulados\PID_OUT.mat", 'r') as archivo:
    datos_simulados_PID = archivo[list(archivo.keys())[0]][:]
datos_experimentales_PID  = scipy.io.loadmat(r"datos_pid\experimentales\PID_OUT.mat")
datos_experimentales_PID  = datos_experimentales_PID[list(datos_experimentales_PID.keys())[0]]

# %%
tiempo_datos_simulados_pid=datos_simulados_PID[:,0]
valor_datos_simulados_pid=datos_simulados_PID[:,1]

tiempo_datos_experimentales_pid=datos_experimentales_PID[0]
valor_datos_experimentales_pid=datos_experimentales_PID[1]

# %%
valor_datos_simulados_pid
# Out:
# array([0.        , 0.29116667, 0.45867692, 0.60228957, 0.70151214,
#        0.78609505, 0.84142117, 0.89246184, 0.92219608, 0.95381578,
#        0.96868518, 0.98905991, 0.99529078, 1.00916387, 1.01036852,
#        1.02049206, 1.01876612, 1.02673694, 1.023296  , 1.03004064,
#        1.02558977, 1.03164584, 1.02659385, 1.03227336, 1.02685719,
#        1.03234122, 1.0266981 , 1.0320918 , 1.02630109, 1.03166552,
#        1.02577303, 1.03114371, 1.02517576, 1.03057338, 1.02454499,
#        1.02998163, 1.02390128, 1.02938404, 1.0232564 , 1.02878949,
#        1.02261703, 1.02820298, 1.02198688, 1.02762726, 1.02136796,
#        1.02706379, 1.02076131, 1.02651327, 1.02016736, 1.02597596,
#        1.01958626])

# %% [markdown]
# sennal de entrada

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir los parámetros del escalón
t_inicio = -0.1  # Tiempo de inicio de la gráfica en segundos
t_subida = 0     # Tiempo en el que sube a 1 V
t_fin = 0.5      # Tiempo en el que baja a 0 V
amplitud = 1.0   # Amplitud del escalón
resolucion = 0.001  # Resolución temporal en segundos

# Crear el vector de tiempo desde -0.1 hasta 0.5 segundos
t = np.arange(t_inicio, t_fin + resolucion, resolucion)
# Crear el vector de señal escalón: comienza en 0, sube a 1 en t=0 y baja a 0 en t=0.5
escalon = np.where(t >= t_subida, amplitud, 0)
#escalon[t >= t_fin] = 0  # Baja a 0 en t=0.5


# Graficar el escalón
plt.figure(figsize=(8, 4))
plt.step(t, escalon, where='post', label='Señal de entrada')
plt.xlabel('Tiempo (s)')
plt.ylabel('Voltaje (V)')
plt.title('Señal de entrada simulada')
plt.ylim(-0.1, 1.1)  # Ajuste de límites para visualizar mejor el cambio
plt.xlim(-0.01, 0.51)  # Limitar el eje x para mostrar el rango deseado
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Sennal de entarda experimental

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir los parámetros del escalón
t_inicio = -0.1  # Tiempo de inicio de la gráfica en segundos
t_subida = 0     # Tiempo en el que sube a 1 V
t_fin = 0.5      # Tiempo en el que baja a 0 V
amplitud = 1.0   # Amplitud del escalón
resolucion = 0.001  # Resolución temporal en segundos

# Crear el vector de tiempo desde -0.1 hasta 0.5 segundos
t = np.arange(t_inicio, t_fin + resolucion, resolucion)
# Crear el vector de señal escalón: comienza en 0, sube a 1 en t=0 y baja a 0 en t=0.5
escalon = np.where(t >= t_subida, amplitud, 0)
#escalon[t >= t_fin] = 0  # Baja a 0 en t=0.5

# Graficar el escalón
plt.figure(figsize=(8, 4))
plt.step(t, escalon, where='post', label='Señal de entrada')
plt.xlabel('Tiempo (s)')
plt.ylabel('Voltaje (V)')
plt.title('Señal de entrada experimental')
plt.ylim(-0.1, 1.1)  # Ajuste de límites para visualizar mejor el cambio
plt.xlim(-0.01, 0.51)  # Limitar el eje x para mostrar el rango deseado
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(tiempo_datos_simulados_pid, valor_datos_simulados_pid, label='PID Simulado')
plt.title('Salida PID Simulada')
plt.xlabel('Tiempo [ms]')
plt.ylabel('Amplitud [V]')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(tiempo_datos_experimentales_pid, valor_datos_experimentales_pid, label='PID Experimental')
plt.title('Salida PID Experimental')
plt.xlabel('Tiempo [ms]')
plt.ylabel('Amplitud [V]')
plt.legend()
plt.grid()
plt.show()

# %%
# Supongamos que tienes dos vectores de datos ya cargados
vector1 = np.array(valor_datos_simulados_pid)  # Datos del primer vector
vector2 = np.array(valor_datos_experimentales_pid)  # Datos del segundo vector

# Calcular el error promedio absoluto (MAE)
mae = np.mean(np.abs(vector1 - vector2))
print(f"Error Promedio Absoluto (MAE): {mae}")

# Calcular la raíz del error cuadrático medio (RMSE)
rmse = np.sqrt(np.mean((vector1 - vector2) ** 2))
print(f"Raíz del Error Cuadrático Medio (RMSE): {rmse}")

mse = np.mean((vector1 - vector2) ** 2)
print("Error Cuadrático Medio (MSE):", mse)
# Out:
# Error Promedio Absoluto (MAE): 0.0
# Raíz del Error Cuadrático Medio (RMSE): 0.0
# Error Cuadrático Medio (MSE): 0.0
